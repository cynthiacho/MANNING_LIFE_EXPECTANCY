# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)

# %%
import string, random
import pandas as pd
pd.options.display.max_colwidth = 10

# %%
area = pd.read_csv('area.csv')
area.head()
# Out:
#   State;TotalRank;TotalSqMi;TotalKmQ;LandRank;LandSqMi;LandKmQ;LandPer;WaterRank;WaterSqMi;WaterKmQ;WaterPer
# 0  Alaska...
# 1  Texas;...
# 2  Califo...
# 3  Montan...
# 4  New Me...

# %%
# Read a csv file to a dataframe with delimiter as space or tab
# Read a csv file to a dataframe with delimiter as space or tab
area =  pd.read_csv('area.csv',  sep=';', engine='python')
#print('Contents of Dataframe : ')
area
# Out:
#         State  TotalRank  TotalSqMi  TotalKmQ  LandRank   LandSqMi  LandKmQ  \
# 0      Alaska          1  665384.04   1723337         1  570640.95  1477953
# 1       Texas          2  268596.46    695662         2  261231.71   676587
# 2   Califo...          3  163694.74    423967         3  155779.22   403466
# 3     Montana          4  147039.71    380831         4  145545.80   376962
# 4   New Me...          5  121590.30    314917         5  121298.15   314161
# 5     Arizona          6  113990.30    295234         6  113594.08   294207
# 6      Nevada          7  110571.82    286380         7  109781.18   284332
# 7    Colorado          8  104093.67    269601         8  103641.89   268431
# 8      Oregon          9   98378.54    254799        10   95988.01   248608
# 9     Wyoming         10   97813.01    253335         9   97093.14   251470
# 10   Michigan         11   96713.51    250487        22   56538.90   146435
# ...

# %%
area_clean = pd.read_csv('area_clean.csv')
area_clean
# Out:
#         State  TotalSqMi  TotalKmQ   LandSqMi  LandKmQ  LandPer  WaterSqMi  \
# 0     Alabama   52420.07    135767   50645.33   131171    96.61    1774.74
# 1      Alaska  665384.04   1723337  570640.95  1477953    85.76   94743.10
# 2     Arizona  113990.30    295234  113594.08   294207    99.65     396.22
# 3    Arkansas   53178.55    137732   52035.48   134771    97.85    1143.07
# 4   Califo...  163694.74    423967  155779.22   403466    95.16    7915.52
# 5    Colorado  104093.67    269601  103641.89   268431    99.57     451.78
# 6   Connec...    5543.41     14357    4842.36    12542    87.35     701.06
# 7    Delaware    2488.72      6446    1948.54     5047    78.29     540.18
# 8     Florida   65757.70    170312   53624.76   138887    81.55   12132.94
# 9     Georgia   59425.15    153910   57513.49   148959    96.78    1911.66
# 10     Hawaii   10931.72     28313    6422.63    16635    58.75    4509.09
# ...

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)

# %%
import string, random
import pandas as pd
pd.options.display.max_colwidth = 10

# %%
crime =  pd.read_csv('crime.csv',  sep=';', engine='python')
#print('Contents of Dataframe : ')
crime
# Out:
#         State Population\n(total inhabitants) \n(2015) [2]  \
# 0     Alabama  4,853,875
# 1      Alaska    737,709
# 2     Arizona  6,817,565
# 3    Arkansas  2,977,853
# 4   Califo...  38,993...
# ..        ...        ...
# 57          b        NaN
# 58                   NaN
# 59          c        NaN
# 60                   NaN
# 61          d        NaN
#
#    Murders and\nNonnegligent\nManslaughter\n(total deaths) \n(2015) [1]  \
# 0         348
# 1          59
# 2         306
# 3         181
# 4       1,861
# ..        ...
# 57        NaN
# 58        NaN
# 59        NaN
# 60        NaN
# 61        NaN
#
#    Murders\n(total deaths) \n(2015) [3]  \
# 0      â€”[a]
# 1          57
# 2         278
# 3         164
# 4       1,861
# ..        ...
# 57        NaN
# 58        NaN
# 59        NaN
# 60        NaN
# 61        NaN
#
#    Gun Murders\n(total deaths) \n(2015) [3]  Gun\nOwnership\n(%) \n(2013) [4]  \
# 0      â€”[a]                                     48.9
# ...

# %%
crime.columns
# Out:
# Index(['State', 'Population\n(total inhabitants) \n(2015) [2]',
#        'Murders and\nNonnegligent\nManslaughter\n(total deaths) \n(2015) [1]',
#        'Murders\n(total deaths) \n(2015) [3]',
#        'Gun Murders\n(total deaths) \n(2015) [3]',
#        'Gun\nOwnership\n(%) \n(2013) [4]',
#        'Murder and\nNonnegligent\nManslaughter\nRate\n(per 100,000) \n(2015)',
#        'Murder Rate\n(per 100,000) \n(2015)',
#        'Gun\nMurder Rate\n(per 100,000) \n(2015)'],
#       dtype='object')

# %%
crime_clean = pd.read_csv('crime_clean.csv')
crime_clean

# %%
education =  pd.read_csv('education.csv',  sep=';', engine='python')
#print('Contents of Dataframe : ')

education
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   State,...  % High...  High S...  % Bach...  Bachel...  % Adva...
# 1   Â Montana      93.0%          1      30.7%         21      10.1%
# 2   Â New ...      92.8%          2      36.0%          9      13.8%
# 3   Â Minn...      92.8%          3      34.8%         11      11.8%
# 4   Â Wyoming      92.8%          4      26.7%         41       9.3%
# 5    Â Alaska      92.4%          5      29.0%         28      10.4%
# 6   Â Nort...      92.3%          6      28.9%         29       7.8%
# 7   Â Vermont      92.3%          7      36.8%          8      15.0%
# 8     Â Maine      92.1%          8      30.3%         23      10.9%
# 9      Â Iowa      91.8%          9      27.7%         36       9.0%
# 10     Â Utah      91.8%         10      32.5%         16      11.0%
# 11  Â Wisc...      91.7%         11      29.0%         27       9.9%
# 12   Â Hawaii      91.6%         12      32.0%         19      10.8%
# ...

# %%
education_clean =  pd.read_csv('education.csv',  sep=';', engine='python')
#print('Contents of Dataframe : ')

education_clean
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   State,...  % High...  High S...  % Bach...  Bachel...  % Adva...
# 1   Â Montana      93.0%          1      30.7%         21      10.1%
# 2   Â New ...      92.8%          2      36.0%          9      13.8%
# 3   Â Minn...      92.8%          3      34.8%         11      11.8%
# 4   Â Wyoming      92.8%          4      26.7%         41       9.3%
# 5    Â Alaska      92.4%          5      29.0%         28      10.4%
# 6   Â Nort...      92.3%          6      28.9%         29       7.8%
# 7   Â Vermont      92.3%          7      36.8%          8      15.0%
# 8     Â Maine      92.1%          8      30.3%         23      10.9%
# 9      Â Iowa      91.8%          9      27.7%         36       9.0%
# 10     Â Utah      91.8%         10      32.5%         16      11.0%
# 11  Â Wisc...      91.7%         11      29.0%         27       9.9%
# 12   Â Hawaii      91.6%         12      32.0%         19      10.8%
# ...

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)

# %%
import string, random
import pandas as pd
pd.options.display.max_colwidth = 10

# %%
income_clean =  pd.read_csv('income_clean.csv',  sep=',', engine='python')
#print('Contents of Dataframe : ')

income_clean
# Out:
#         State  Income2017  Income2016  Income2015  Income2014  Income2013  \
# 0     Alabama      48123       46257       44765       42830       42849
# 1      Alaska      73181       76440       73355       71583       72237
# 2     Arizona      56581       53558       51492       50068       48510
# 3    Arkansas      45869       45907       42798       44922       39376
# 4   Califo...      71805       67739       64500       61933       60190
# 5    Colorado      69117       65685       63909       61303       58823
# 6   Connec...      74168       73433       71346       70048       67098
# 7    Delaware      62852       61757       61255       59716       57846
# 8   Distri...      82336       75506       75628       71648       67572
# 9     Florida      52594       50860       49426       47463       46036
# 10    Georgia      56183       53559       51244       49321       47829
# 11     Hawaii      77765       74511       73486       69592       68020
# ...

# %%
life_expectancy =  pd.read_csv('life_expectancy.csv',  sep=';', engine='python')
#print('Contents of Dataframe : ')

life_expectancy
# Out:
#         State LifeExp2018  LifeExp2010  MaleLifeExp  FemLifeExp
# 0    Â Hawaii       82.3        81.4         79.3         85.3
# 1   Â Cali...       81.6        80.6         79.4         83.8
# 2   Â Puer...       81.3        78.7         77.6         84.7
# 3   Â New ...       81.3        80.3         79.0         83.4
# 4   Â U.S....       81.2        79.2         76.3         85.6
# 5   Â Minn...       81.0        80.8         79.0         83.0
# 6   Â Conn...       80.9        80.7         78.7         83.0
# 7      Â Guam       80.7        78.2         77.6         83.8
# 8   Â Colo...       80.5        80.1         78.5         82.5
# 9   Â Mass...       80.5        80.5         78.2         82.6
# 10  Â Wash...       80.4        80.1         78.4         82.4
# 11  Â New ...       80.4        80.0         78.2         82.5
# 12  Â Florida       80.0        79.0         77.3         82.6
# 13  Â Arizona       79.9        79.3         77.5         82.3
# ...

# %%
life_expectancy_all =  pd.read_csv('life_expectancy_all.csv',  sep=',', engine='python')
#print('Contents of Dataframe : ')

life_expectancy_all
# Out:
#         State  HSGradPer  BADegPer  AdvDegPer  LifeExp2018  LifeExp2010  \
# 0     Alabama       85.3      24.5        9.1       75.4         75.4
# 1      Alaska       92.4      29.0       10.4       78.8         78.0
# 2     Arizona       82.1      28.4       10.7       79.9         79.3
# 3    Arkansas       85.6      22.0        7.9       75.9         76.0
# 4   Califo...       82.5      32.6       12.2       81.6         80.6
# 5    Colorado       91.1      39.4       14.6       80.5         80.1
# 6   Connec...       90.2      38.4       17.0       80.9         80.7
# 7    Delaware       89.3      31.0       12.9       78.4         78.3
# 8     Florida       87.6      28.5       10.3       80.0         79.0
# 9     Georgia       86.3      29.9       11.4       77.8         77.3
# 10     Hawaii       91.6      32.0       10.8       82.3         81.4
# 11      Idaho       90.2      26.8        8.5       79.3         79.4
# ...

# %%
life_expectancy_clean =  pd.read_csv('life_expectancy_clean.csv',  sep=',', engine='python')
#print('Contents of Dataframe : ')

life_expectancy_clean
# Out:
#         State  LifeExp2018  LifeExp2010  MaleLifeExp  FemLifeExp
# 0     Alabama       75.4         75.4         72.6         78.1
# 1      Alaska       78.8         78.0         76.7         81.2
# 2   Americ...       74.8         74.0         73.0         77.0
# 3     Arizona       79.9         79.3         77.5         82.3
# 4    Arkansas       75.9         76.0         73.1         78.6
# 5   Califo...       81.6         80.6         79.4         83.8
# 6    Colorado       80.5         80.1         78.5         82.5
# 7   Connec...       80.9         80.7         78.7         83.0
# 8    Delaware       78.4         78.3         76.2         80.6
# 9   Distri...       78.6         76.5         75.7         81.3
# 10    Florida       80.0         79.0         77.3         82.6
# 11    Georgia       77.8         77.3         75.4         80.0
# 12       Guam       80.7         78.2         77.6         83.8
# 13     Hawaii       82.3         81.4         79.3         85.3
# ...

# %%
region_clean =  pd.read_csv('region_clean.csv',  sep=',', engine='python')
#print('Contents of Dataframe : ')

region_clean
# Out:
#         State Abb     Region   Division
# 0     Alabama  AL      South  East S...
# 1      Alaska  AK       West    Pacific
# 2     Arizona  AZ       West   Mountain
# 3    Arkansas  AR      South  West S...
# 4   Califo...  CA       West    Pacific
# 5    Colorado  CO       West   Mountain
# 6   Connec...  CT  Northeast  New En...
# 7    Delaware  DE      South  South ...
# 8     Florida  FL      South  South ...
# 9     Georgia  GA      South  South ...
# 10     Hawaii  HI       West    Pacific
# 11      Idaho  ID       West   Mountain
# 12   Illinois  IL  North ...  East N...
# 13    Indiana  IN  North ...  East N...
# 14       Iowa  IA  North ...  West N...
# 15     Kansas  KS  North ...  West N...
# 16   Kentucky  KY      South  East S...
# 17  Louisiana  LA      South  West S...
# 18      Maine  ME  Northeast  New En...
# 19   Maryland  MD      South  South ...
# 20  Massac...  MA  Northeast  New En...
# 21   Michigan  MI  North ...  East N...
# ...

# %%
state_data_clean =  pd.read_csv('state_data_clean.csv',  sep=',', engine='python')
#print('Contents of Dataframe : ')

state_data_clean
# Out:
#         State  HSGradPer  BADegPer  AdvDegPer  LifeExp2018  MaleLifeExp  \
# 0      Alaska       92.4      29.0       10.4       78.8         76.7
# 1     Arizona       82.1      28.4       10.7       79.9         77.5
# 2    Arkansas       85.6      22.0        7.9       75.9         73.1
# 3   Califo...       82.5      32.6       12.2       81.6         79.4
# 4    Colorado       91.1      39.4       14.6       80.5         78.5
# 5   Connec...       90.2      38.4       17.0       80.9         78.7
# 6    Delaware       89.3      31.0       12.9       78.4         76.2
# 7     Georgia       86.3      29.9       11.4       77.8         75.4
# 8      Hawaii       91.6      32.0       10.8       82.3         79.3
# 9       Idaho       90.2      26.8        8.5       79.3         77.4
# 10   Illinois       88.6      33.4       13.0       79.3         77.0
# 11    Indiana       88.3      25.3        9.2       77.0         74.6
# ...
